# %% [markdown]
# <a href="https://colab.research.google.com/github/dihanageisela/KKA-X-Semester-1-dihanageisela/blob/main/Tipe_variabel_dihana_x_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: dihana geisela
#
# Kelas:x.2
#
# No.Absen:8

# %% [markdown]
# Konsep Dasar variabel

# %%
print("dihanageisela.2025@gmail.com")
print("dihanageisela.2025@gmail.com")
print("dihanageisela.2025@gmail.com")
# Out:
# dihanageisela.2025@gmail.com
# dihanageisela.2025@gmail.com
# dihanageisela.2025@gmail.com

# %%
email_user ="dihanageisela.2025@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# dihanageisela.2025@gmail.com
# dihanageisela.2025@gmail.com
# dihanageisela.2025@gmail.com

# %% [markdown]
# Peraturan penulisan nilai variabel

# %%
#Hanya boleh menggunakan huruf, angka dan underscore
harga telur =15000
print(harga telur)
# Out:
#   File "/tmp/ipython-input-962244350.py", line 2
#     harga telur =15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur= 15000
print(hargatelur)
# Out:
# 15000

# %%
#tidak boleh diawali oleh angka
1_nama siswa="Ahmad Dhani"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-2074382309.py", line 2
#     1_nama siswa="Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#tidak boleh menggunakan kata kunci python
if="handayani"
# Out:
#   File "/tmp/ipython-input-2344591504.py", line 2
#     if="handayani"
#       ^
# SyntaxError: invalid syntax

# %%
IF ="handayani"

# %%
print ="Noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1271395334.py in <cell line: 0>()
#       1 print ="Noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print ="Noor"
print(Print)
# Out:
# Noor

# %%
#sensitif terhadap penulisan kapital
USIA = 17

print(usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4174408746.py in <cell line: 0>()
#       2 USIA = 17
#       3
# ----> 4 print(usia)
#
# NameError: name 'usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_="Fazel wardana"

# %%
_="Lia Wati"

# %%
print(_)
# Out:
# Lia Wati

# %% [markdown]
# Assignment

# %%
#Single assignment
bb_fazel =55
bb_dani  =60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#Multiple assignment
bb_fazel, bb_dani = 55,60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb_dani =55, 60,70
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-831142636.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani =55, 60,70
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1, nama_siswa_2 ="deni", "doni"

print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel, bb_dani, bb_adli=55, 60
print(bb_fazel)
print(bb_dani)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2307598621.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani, bb_adli=55, 60
#       2 print(bb_fazel)
#       3 print(bb_dani)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#chain assignment
bb_hasbi=bb_dani =60

print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# Cara penulisan operator pada Python

# %%
#tampa variabel
print(9+6)
# Out:
# 15

# %%
print("Shinta")
# Out:
# Shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#operand di simpan ke variabel
jumlah_hp_habibi=10
jumlah_hp_syauqi=6

print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#Hasil operand disimpan ke variabel

# %%
a ="Faris"
print (a)

# %% [markdown]
# Operator logika

# %%
print(6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print (8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False
